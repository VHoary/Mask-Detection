# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="XR70DZRqCOj12fausGtI")
project = rf.workspace("24mask").project("maskseg-pwfph")
dataset = project.version(3).download("yolov8")

# %%
# !yolo task=detect mode=train model=yolov8n.pt data="C:\Users\fzopr\Documents\Code\Python\DIP Project\App\MASKseg-3\data.yaml" epochs=100 imgsz=640
# Out:
# ...
#
#   0%|          | 0.00/6.23M [00:00<?, ?B/s]
#  90%|█████████ | 5.63M/6.23M [00:00<00:00, 58.1MB/s]
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 61.2MB/s]
# Ultralytics YOLOv8.0.202  Python-3.11.6 torch-2.1.0+cpu CPU (AMD Ryzen 7 5800HS with Radeon Graphics)
# ...

# %%
Image(filename=f"C:/Users/fzopr/Documents/Code/Python/DIP Project/App/runs/detect/train/labels_correlogram.jpg", width=600)

# %%
Image(filename=f"C:/Users/fzopr/Documents/Code/Python/DIP Project/App/runs/detect/train/results.png", width=600)

# %%
# !yolo task=detect mode=val model="C:/Users/fzopr/Documents/Code/Python/DIP Project/App/runs/detect/train/weights/best.pt" data="C:/Users/fzopr/Documents/Code/Python/DIP Project/App/MASKseg-3/data.yaml"
# Out:
# Ultralytics YOLOv8.0.202  Python-3.11.6 torch-2.1.0+cpu CPU (AMD Ryzen 7 5800HS with Radeon Graphics)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# val: Scanning C:\Users\fzopr\Documents\Code\Python\DIP Project\App\MASKseg-3\valid\labels.cache... 44 images, 0 backgrounds, 0 corrupt: 100%|██████████| 44/44 [00:00<?, ?it/s]
# val: Scanning C:\Users\fzopr\Documents\Code\Python\DIP Project\App\MASKseg-3\valid\labels.cache... 44 images, 0 backgrounds, 0 corrupt: 100%|██████████| 44/44 [00:00<?, ?it/s]
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/3 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  33%|███▎      | 1/3 [00:02<00:04,  2.09s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  67%|██████▋   | 2/3 [00:04<00:02,  2.05s/it]
# ...

# %%
# !yolo task=detect mode=predict model="C:/Users/fzopr/Documents/Code/Python/DIP Project/App/runs/detect/train/weights/best.pt" conf=0.5 
source="C:/Users/fzopr/Documents/Code/Python/DIP Project/App/MASKseg-3/train/images"
# Out:
# Ultralytics YOLOv8.0.202  Python-3.11.6 torch-2.1.0+cpu CPU (AMD Ryzen 7 5800HS with Radeon Graphics)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/151 C:\Users\fzopr\Documents\Code\Python\DIP Project\App\MASKseg-3\train\images\0002_jpg.rf.22ccbbd34b777fbde0b83032926cd4be.jpg: 640x640 1 MASK, 101.3ms
# image 2/151 C:\Users\fzopr\Documents\Code\Python\DIP Project\App\MASKseg-3\train\images\0004_jpg.rf.3ef17fa9ad23558590aab6ad13f496be.jpg: 640x640 1 MASK, 80.4ms
# image 3/151 C:\Users\fzopr\Documents\Code\Python\DIP Project\App\MASKseg-3\train\images\0005_jpg.rf.9749d107925ff63a50499a536f5cc764.jpg: 640x640 1 MASK, 79.2ms
# image 4/151 C:\Users\fzopr\Documents\Code\Python\DIP Project\App\MASKseg-3\train\images\0006_jpg.rf.c6b95a52dfbac16a250a7b9e413b5dca.jpg: 640x640 1 MASK, 80.1ms
# ...
